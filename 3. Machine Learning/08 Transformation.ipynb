# %% [markdown]
# <div style="text-align: center; font-family: 'Times New Roman', Times, serif; background-color: #f5f5f5; padding: 20px; border-radius: 10px; box-shadow: 0 0 10px rgba(0, 0, 0, 0.1);">
#
#   <h1 style="color: #333; text-decoration: underline;">Python</h1>
#   <h1 style="color: #333; text-decoration: underline;">Machine Learning</h1>
#   <div style="font-style: italic; margin-top: 10px; color: #555;">Notebook Author: Shahzaib Yaqoob</div>
#   <div style="font-weight: bold; margin-top: 5px; color: #555;">Gmail: shahzaibmalik4488@gmail.com</div>
#   <p style="margin-top: 20px; color: #777;">Welcome to the world of Python and Machine Learning! Feel free to explore and innovate.</p>
#
#   <!-- Navigation Links -->
#   <div style="margin-top: 20px;">
#     <a href="#tutorials" style="color: #555; margin-right: 20px;">Tutorials</a>
#     <a href="#resources" style="color: #555; margin-right: 20px;">Resources</a>
#     <a href="#examples" style="color: #555;">Examples</a>
#   </div>
#
#   <!-- Code Snippet -->
#   <div style="margin-top: 20px;">
#     <code style="background-color: #ddd; padding: 5px; color:#555">print("Hello, Python and Machine Learning!")</code>
#   </div>
#
#   <!-- Social Media Links -->
#   <div style="margin-top: 20px;">
#     <a href="https://github.com/shahzaiby" style="color: #555; margin-right: 20px;">GitHub</a>
#     <a href="https://www.linkedin.com/in/shahzaibyaqoob/" style="color: #555; margin-right: 20px;">LinkedIn</a>
#     <a href="https://twitter.com/shahzaib" style="color: #555;">Twitter</a>
#   </div>
#
#   <!-- Additional Styling -->
#   <style>
#     /* Add your additional styling here */
#     a:hover {
#       text-decoration: underline;
#     }
#   </style>
#
#   <!-- Footer -->
#   <div style="margin-top: 20px; color: #555;">
#     &copy; 2023 Shahzaib Yaqoob. All rights reserved.
#   </div>
#
# </div>

# %%
# import library
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.seed(0)
random_ = np.random.exponential(size=100,scale=2)
df_random_=pd.DataFrame(random_,columns=["Values"])
df_random_
# Out:
#       Values
# 0   1.591749
# 1   2.511862
# 2   1.846446
# 3   1.574402
# 4   1.102097
# ..       ...
# 95  0.404701
# 96  1.766258
# 97  0.040625
# 98  3.531482
# 99  0.009413
#
# [100 rows x 1 columns]

# %%
sns.histplot(data=df_random_['Values'],kde=True)
# Out:
# <Axes: xlabel='Values', ylabel='Count'>

# %%
from sklearn.preprocessing import power_transform , quantile_transform

# %%
# Reshape for Box-Cox transformation
pt_boxcox= df_random_["Values"].values.reshape(-1, 1)
df_random_['values_boxcox'] = power_transform(pt_boxcox, method='box-cox', standardize=True)

# Reshape for Yeo-Johnson transformation
pt_yeo_johnsaon = df_random_["Values"].values.reshape(-1, 1)
df_random_['yeo_johnson']= power_transform(pt_yeo_johnsaon, method='yeo-johnson', standardize=True)

# Quantile_transf
df_random_["Quantile_transf"] = quantile_transform(df_random_[['Values']], n_quantiles=len(df_random_), random_state=0)

# %%
df_random_.head()
# Out:
#      Values  values_boxcox  yeo_johnson  Quantile_transf
# 0  1.591749       0.247092     0.265186         0.555556
# 1  2.511862       0.692947     0.765195         0.777778
# 2  1.846446       0.386749     0.426230         0.626263
# 3  1.574402       0.236981     0.253406         0.545455
# 4  1.102097      -0.077784    -0.117999         0.434343

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 10)) 

# Plot Box-Cox transformed data
sns.histplot(data=df_random_['values_boxcox'], kde=True, ax=axes[0,0])
axes[0,0].set_title('Box-Cox Transformation')

# Plot Yeo-Johnson transformed data
sns.histplot(data=df_random_['yeo_johnson'], kde=True, ax=axes[0,1])
axes[0,1].set_title('Yeo-Johnson Transformation')

sns.histplot(data=df_random_, kde=True ,ax=axes[1, 0])
axes[1, 0].set_title('First Hist Plot')


sns.histplot(data=df_random_['Quantile_transf'], kde=True ,ax=axes[1, 1])
axes[1, 1].set_title('Quantile_transft')
# Out:
# Text(0.5, 1.0, 'Quantile_transft')
