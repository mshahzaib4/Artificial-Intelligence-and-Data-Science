# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import r2_score

# %%
np.random.seed(42)
x = 2 * np.random.rand(100, 1)
y = 4 + 3 * X + 1.5 * X**2 + np.random.randn(100, 1)

# %%
plt.plot(x,y,".",color="red")
plt.xlabel("X label")
plt.ylabel("Y Label")
# Out:
# Text(0, 0.5, 'Y Label')

# %% [markdown]
# # PolynomialFeatures

# %%
PolynomialFeature=PolynomialFeatures(degree=2)
X_poly=PolynomialFeature.fit_transform(x)

# %%
# Simple Linear Regression
X_train, X_test, Y_train, Y_test=train_test_split(x,y,random_state=42,test_size=0.2)
model=LinearRegression().fit(X_train,Y_train)
predict=model.predict(X_test)
print("R2 Score : ",r2_score(Y_test,predict))
# Out:
# R2 Score :  0.9278557667442914

# %%
plt.figure(figsize=(7,5))
plt.scatter(X_train, Y_train,color="red",marker=".")
plt.plot(X_train,model.predict(X_train),color="Green")

# %%
# Create polynomial features
poly = PolynomialFeatures(degree=2)
X_train_poly = poly.fit_transform(X_train)
X_test_poly = poly.transform(X_test)

print("Original X_train value \n", X_train[0])
print("Polynomial Features \n", X_train_poly[0])

# Fit a linear regression model
model = LinearRegression().fit(X_train_poly, Y_train)
poly_predictions = model.predict(X_test_poly)

# Evaluate the model
r2 = r2_score(Y_test, poly_predictions)
print("R2 Score:", r2)
# Out:
# Original X_train value
#  [1.84374847]
# Polynomial Features
#  [1.         1.84374847 3.39940842]
# R2 Score: 0.9511063423293336

# %%
# Visualize the results
X_range = np.linspace(0, 2, 100).reshape(-1, 1)
X_range_poly = poly.transform(X_range)
y_range_pred = model.predict(X_range_poly)

plt.scatter(X_test, Y_test, marker=".", color="red", label="Actual")
plt.scatter(X_test, poly_predictions, marker=".", color="blue", label="Predicted")
plt.plot(X_range, y_range_pred, color='green', label=f'Degree-{2} Polynomial Regression Line')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.show()
