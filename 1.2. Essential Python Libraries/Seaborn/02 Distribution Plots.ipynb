# %% [markdown]
# ### Some Seaborn Distribution Plots
# - **Hist plot**
# - **Kde plot**
# - **Rug plot**
# - **Ecdf plot**
# - **Boxen plot**
# - **Violin plot**
# - **Qq plot**
# - **Ridge plot**
# - **Dis plot**

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
Data=pd.read_csv("deliveries.csv")
Data.head(2)
# Out:
#    match_id   season  start_date                             venue  innings  \
# 0         1  2023/24  2023-10-05  Narendra Modi Stadium, Ahmedabad        1
# 1         1  2023/24  2023-10-05  Narendra Modi Stadium, Ahmedabad        1
#
#    ball batting_team bowling_team      striker non_striker  ... extras  wides  \
# 0   0.1      England  New Zealand  JM Bairstow    DJ Malan  ...      0    NaN
# 1   0.2      England  New Zealand  JM Bairstow    DJ Malan  ...      0    NaN
#
#    noballs  byes  legbyes  penalty  wicket_type  player_dismissed  \
# 0      NaN   NaN      NaN      NaN          NaN               NaN
# 1      NaN   NaN      NaN      NaN          NaN               NaN
#
#   other_wicket_type other_player_dismissed
# 0               NaN                    NaN
# 1               NaN                    NaN
#
# [2 rows x 22 columns]

# %%
Data.drop(['wides',	'noballs',	'byes',	'legbyes',	'penalty',	'wicket_type',	'player_dismissed',	'other_wicket_type','other_player_dismissed'],axis=1,inplace=True)

# %%
Data.head(2)
# Out:
#    match_id   season  start_date                             venue  innings  \
# 0         1  2023/24  2023-10-05  Narendra Modi Stadium, Ahmedabad        1
# 1         1  2023/24  2023-10-05  Narendra Modi Stadium, Ahmedabad        1
#
#    ball batting_team bowling_team      striker non_striker    bowler  \
# 0   0.1      England  New Zealand  JM Bairstow    DJ Malan  TA Boult
# 1   0.2      England  New Zealand  JM Bairstow    DJ Malan  TA Boult
#
#    runs_off_bat  extras
# 0             0       0
# 1             6       0

# %% [markdown]
# # **`1.` Create Disp Plot**

# %%
plt.figure(figsize=(15, 6))

plt.suptitle("Deliveries")
plt.xlabel("Match Season")
plt.ylabel("Match Venue")
sns.histplot(data=Data,x='match_id')
# Out:
# <Axes: xlabel='Match Season', ylabel='Match Venue'>

# %% [markdown]
# # **`2.` Create Kde Plot**

# %%
plt.figure(figsize=(15, 6))

plt.suptitle("Deliveries")  # Set a title for the entire figure
plt.xlabel("Match Season")
plt.ylabel("Match Venue")

sns.kdeplot(data=Data, x='match_id', fill=True)  # Use kdeplot for KDE plot

plt.show()

# %% [markdown]
# # **`3.` Create Rug Plot**

# %%
sns.displot(data=Data,x='match_id',kind='kde',rug=True)

# %% [markdown]
# # **`4.` Create Ecdf Plot**

# %%
plt.figure(figsize=(15, 6))

plt.suptitle("Deliveries")
plt.xlabel("Match Season")
plt.ylabel("Match Venue")
sns.ecdfplot(data=Data, y="venue",  hue="innings")
plt.tight_layout()

# %% [markdown]
# # **`5.` Create Boxen Plot**

# %%
plt.figure(figsize=(15, 10))

plt.suptitle("Deliveries")  # Set a title for the entire figure
plt.xlabel("Match Season")
plt.ylabel("Match Venue")
sns.boxenplot(data=Data, y="venue", x="season", hue="innings")
plt.tight_layout()

# %%
Data.columns
# Out:
# Index(['match_id', 'season', 'start_date', 'venue', 'innings', 'ball',
#        'batting_team', 'bowling_team', 'striker', 'non_striker', 'bowler',
#        'runs_off_bat', 'extras'],
#       dtype='object')

# %% [markdown]
# # **`6.` Create Violin Plot**

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.violinplot(x='season', y='ball',hue="bowling_team", data=Data)
plt.title('Violin Plot')
# Out:
# Text(0.5, 1.0, 'Violin Plot')

# %% [markdown]
# ## **`7.` Create Q-Q Plot (Quantile-Quantile Plot)**

# %%
import statsmodels.api as sm

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sm.qqplot(x='season', y='ball',hue="bowling_team", data=Data)
plt.title('Violin Plot')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 3
#       1 sns.set(style="whitegrid")
#       2 plt.figure(figsize=(10, 6))
# ----> 3 sm.qqplot(x='season', y='ball',hue="bowling_team", data=Data)
#       4 plt.title('Violin Plot')
#
# File c:\Users\laptop zone\miniconda3\envs\Python_ML\Lib\site-packages\statsmodels\graphics\gofplots.py:691, in qqplot(data, dist, distargs, a, loc, scale, fit, line, ax, **plotkwargs)
#     593 """
#     594 Q-Q plot of the quantiles of x versus the quantiles/ppf of a distribution.
#     595
#    (...)
#     686 .. plot:: plots/graphics_gofplots_qqplot.py
#     687 """
#     688 probplot = ProbPlot(
#     689     data, dist=dist, distargs=distargs, fit=fit, a=a, loc=loc, scale=scale
#     690 )
# --> 691 fig = probplot.qqplot(ax=ax, line=line, **plotkwargs)
#     692 return fig
#
# ...

# %% [markdown]
# # **`2.` Create Residplot Plot**
#
# - The **sns.residplot** function in Seaborn is specifically created to operate with numerical data.

# %%
plt.figure(figsize=(15, 10))
plt.suptitle("Deliveries")
sns.residplot(data=Data, x='match_id', y='innings', lowess=True, scatter_kws={'s': 80}, line_kws={'color': 'red'})
# Out:
# <Axes: xlabel='match_id', ylabel='innings'>
